# %% [markdown]
# <a href="https://colab.research.google.com/github/rkahrya1311/amazon-ml-challenge-2026/blob/arun%2Ffeatures/arun_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
print(a)
# Out:
# 10
